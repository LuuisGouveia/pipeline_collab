# %%
import pandas as pd 
import os

df = pd.read_parquet('../data/unified_data.parquet')
print(df.tail())
# Out:
#     delivery_date client_dentist                   patient  \
# 104    2020-07-28         RAFAEL                   Fabiana
# 105    2020-08-07         RAFAEL              Desconhecido
# 106    2020-08-11         RAFAEL              Desconhecido
# 107    2020-08-31    ODONTOLOGIC  L. F. Melo (Dra Leticia)
# 108    2020-08-31    ODONTOLOGIC    Patricia (Dra Leticia)
#
#                              job  price  quantity  total_price  \
# 104            CERAMICA IMPLANTE  180.0         1        180.0
# 105                   Provisorio   60.0         1         60.0
# 106  Provisorio Lateral Superior   60.0         1         60.0
# 107        Aplicação de Ceramica  120.0         1        120.0
# 108                   Ceramicas   180.0         2        360.0
#
#                                    file_name
# 104       RAFAEL CALEFFI.xlsx - CONTROLE.csv
# 105       RAFAEL CALEFFI.xlsx - CONTROLE.csv
# 106       RAFAEL CALEFFI.xlsx - CONTROLE.csv
# ...
